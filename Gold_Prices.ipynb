# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivithra-19/Data_Analysis/blob/Python/Gold_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cdc9f821-b8a2-440c-b173-7eba25a7d5e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdc9f821-b8a2-440c-b173-7eba25a7d5e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df  = pd.read_csv('data.csv', index_col='date', parse_dates=True)

# %%
df.head()
# Out:
#             price
# date
# 1950-01-01  34.73
# 1950-02-01  34.73
# 1950-03-01  34.73
# 1950-04-01  34.73
# 1950-05-01  34.73

# %%
df.tail()
# Out:
#                price
# date
# 2017-10-01  1280.677
# 2017-11-01  1283.189
# 2017-12-01  1265.674
# 2018-01-01  1332.809
# 2018-02-01  1333.775

# %%
import matplotlib.pyplot as plt
df.plot(figsize=(15, 7))
plt.show()

# %%
start_date = "2000-01-01"
end_date = "2018-01-01"
mask = (df.index >= start_date) & (df.index <= end_date)
df = df.loc[mask]

# %%
df.index.freq = "MS"
df.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date'>

# %%
datayearly = df.rolling(window=12).mean()
datayearly.plot(title="Yearly Avg Gold Prices")
# Out:
# <Axes: title={'center': 'Yearly Avg Gold Prices'}, xlabel='date'>
